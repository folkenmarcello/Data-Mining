# %% [markdown]
# <a href="https://colab.research.google.com/github/folkenmarcello/Data-Mining/blob/main/Linkedin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.linkedin.android',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10,
    filter_score_with=5
    )
   

df_review = pd.DataFrame(np.array(result),columns=['review'])
df_review = df_review.join(pd.DataFrame(df_review.pop('review').tolist()))

df_review.head(1000)
# Out:
#                                             reviewId  ... repliedAt
# 0  gp:AOqpTOHSrkPSNi7pV2wCIMAp-L9660Sn298VbyokYcv...  ...      None
# 1  gp:AOqpTOE94i4noTkOWCC5V1zCqunCBm7AwIbriDExXdl...  ...      None
# 2  gp:AOqpTOGEz_p3fLxMQMKaq4vvNf86E4EDa_mMLb90bd2...  ...      None
# 3  gp:AOqpTOGR7JmNmTnLJkVTtRhVNcWBU9MpGknfuM3VnwD...  ...      None
# 4  gp:AOqpTOFLWk-Y_PWq5QsbqGsZWcWeR5eazWPqXnJmfuc...  ...      None
# 5  gp:AOqpTOFgsm99Oc2dMeqKAwssu1MQ2JFOr5ASk7BrsL6...  ...      None
# 6  gp:AOqpTOHTUf0NYTaSM0YwUPgdpn1mUab-ei7M6-xdgMp...  ...      None
# 7  gp:AOqpTOHMjve_mS6NOszFwO2-abVJe-spGhtV1CrER5z...  ...      None
# 8  gp:AOqpTOGCyIx0BIHRcFXj_3blBYbEksaUDEFgaV9I3eW...  ...      None
# 9  gp:AOqpTOFCs8oZEkS5pui9lwgEsKM0hQ4d0hd6eFGQr8a...  ...      None
#
# [10 rows x 10 columns]

# %%
pip install google-play-scraper
# Out:
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.2-py3-none-any.whl size=24393 sha256=9acaaf4f02c1fdcf3d673daa57b411bf46a3228677ccab1eb038853d942587e1
#   Stored in directory: /root/.cache/pip/wheels/98/99/eb/bbb9d24a5c526980647efc10336eaaeffcf07749f581111128
# Successfully built google-play-scraper
# ...
