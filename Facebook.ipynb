# %% [markdown]
# <a href="https://colab.research.google.com/github/folkenmarcello/Data-Mining/blob/main/Facebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.facebook.lite',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10,
    filter_score_with=5
    )
   

df_review = pd.DataFrame(np.array(result),columns=['review'])
df_review = df_review.join(pd.DataFrame(df_review.pop('review').tolist()))

df_review.head(1000)
# Out:
#                                             reviewId  ... repliedAt
# 0  gp:AOqpTOGcmDI2WaK74mkOO6UnOP33Zc4DtpbsJlKnwJm...  ...      None
# 1  gp:AOqpTOHcVHMTViHIFZ0DN6lLiYxxKL4euckjf7GuI14...  ...      None
# 2  gp:AOqpTOGfq34uDw4Zu08L8FAHJDqoaVA9r7azNpc_7P3...  ...      None
# 3  gp:AOqpTOHX6WY2YY39-Ld5hSZRVxmQN0OZajAXGKob8Dv...  ...      None
# 4  gp:AOqpTOH9myUsXbh4RETjxCsHBg25-DwPzMeCJqCvnzz...  ...      None
# 5  gp:AOqpTOG7eIoMWL7jW9AspFNo4h0hhbiItTgZdlR2Asb...  ...      None
# 6  gp:AOqpTOHsy23eF7AjQSIelSkXbFCbdwbP7G3lh6Z_QTk...  ...      None
# 7  gp:AOqpTOHPFVA-Zhp62gy0SGXtbDvfuY7upTDYDvsjjBJ...  ...      None
# 8  gp:AOqpTOHipwekR_SB03gCPlVViJarN_zo0jbY4B8a5Dr...  ...      None
# 9  gp:AOqpTOHysJWQ32FHN2S6YfhOLTRuUAhBL0u6dHyrGpV...  ...      None
#
# [10 rows x 10 columns]

# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google-play-scraper-1.0.2.tar.gz (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Building wheels for collected packages: google-play-scraper
#   Building wheel for google-play-scraper (setup.py) ... done
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.2-py3-none-any.whl size=24393 sha256=dc9f9441cdfbbf5940496235f6853e78208101c1511621a9f4d23d658f90c315
#   Stored in directory: /root/.cache/pip/wheels/98/99/eb/bbb9d24a5c526980647efc10336eaaeffcf07749f581111128
# Successfully built google-play-scraper
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.0.2
