# %% [markdown]
# <a href="https://colab.research.google.com/github/folkenmarcello/Data-Mining/blob/main/Tiktok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.ss.android.ugc.trill',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10,
    filter_score_with=5
    )
   

df_review = pd.DataFrame(np.array(result),columns=['review'])
df_review = df_review.join(pd.DataFrame(df_review.pop('review').tolist()))

df_review.head(1000)
# Out:
#                                             reviewId  ... repliedAt
# 0  gp:AOqpTOELDjYqUFrNsnztGE2Uz-ZcqcobAekdkD_tGW1...  ...      None
# 1  gp:AOqpTOGTYAOWD6l0LnMFBxa9N_v5nyHxaMBAaB3lSyM...  ...      None
# 2  gp:AOqpTOGnCacQeHknPWSVF5splB5YvNCF_dBAD2S5DaP...  ...      None
# 3  gp:AOqpTOGhUEmoH6SKBRNjeKZhEjEE6NeWiAAt3OclNW6...  ...      None
# 4  gp:AOqpTOH1eM0lN8JCfAhL4SjKrAngKJ62s98SBQ91sbx...  ...      None
# 5  gp:AOqpTOHzwkToMB-7F_gkFaAiiq4_SuRtyC6rIMhFMVo...  ...      None
# 6  gp:AOqpTOENUsZTe7SS99Fde-aYoLYo6JlvUsFEbW6Wd2p...  ...      None
# 7  gp:AOqpTOGFAPVtqeVHEzXPnmdqAh_YQn6OFWiQTK4z2bH...  ...      None
# 8  gp:AOqpTOHami7LSSudGj135EU-zWY0rufZ1jTbNPXyqhR...  ...      None
# 9  gp:AOqpTOH7H4NrkJZ5YgfyLbkud3cIzugi9FTavJWRDG3...  ...      None
#
# [10 rows x 10 columns]
