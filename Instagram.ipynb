# %% [markdown]
# <a href="https://colab.research.google.com/github/folkenmarcello/Data-Mining/blob/main/Instagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.instagram.android',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10,
    filter_score_with=5
    )
   

df_review = pd.DataFrame(np.array(result),columns=['review'])
df_review = df_review.join(pd.DataFrame(df_review.pop('review').tolist()))

df_review.head(1000)
# Out:
#                                             reviewId  ... repliedAt
# 0  gp:AOqpTOE-P6l0iNA_OXx3siZnYrtJBl6sEYQjVE6uT_5...  ...      None
# 1  gp:AOqpTOEFNl4V97gn44szQ-S_1b8N8iwC0Se8ivj0CMh...  ...      None
# 2  gp:AOqpTOFmNbW2bPrDlMIoTMKp3OJA5qLYQ_dfpk8dT7Z...  ...      None
# 3  gp:AOqpTOE6QrQrLvc_cOiXUBXaoGRcHWb7J-HNeJu8X4e...  ...      None
# 4  gp:AOqpTOE6kDJmNsDY3pHipMaoLNlWIagyl_gQshH8zXq...  ...      None
# 5  gp:AOqpTOELbg677pm1aNIE39GNoVUquAZD2rf1MgUSiuD...  ...      None
# 6  gp:AOqpTOHQBz-eYUZiaqYngSBW9W9-z1XYtZOIB7-gNyF...  ...      None
# 7  gp:AOqpTOE7HHPwjKr7G5iJNVlc8g4yG3NdI75pn53zKSB...  ...      None
# 8  gp:AOqpTOEg1atVw9FB12dQB_0j5NVPYWhISGK7g0ns8Qz...  ...      None
# 9  gp:AOqpTOEyB8bnhe667PVxvpfZBSuHZzVmO1dXp3h3ZlS...  ...      None
#
# [10 rows x 10 columns]
